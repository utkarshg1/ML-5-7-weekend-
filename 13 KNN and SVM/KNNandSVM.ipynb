# %% [markdown]
# # KNN algorithm (K-Nearest-Neighbors)
# Suitable for small datasets upto 1000 rows

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ### Step 1 - Data ingestion

# %%
import pandas as pd
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Step 2 - Perform Basic Data Quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df = df.drop_duplicates(keep="first").reset_index(drop=True)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 144           6.7          3.0           5.2          2.3  virginica
# 145           6.3          2.5           5.0          1.9  virginica
# 146           6.5          3.0           5.2          2.0  virginica
# 147           6.2          3.4           5.4          2.3  virginica
# 148           5.9          3.0           5.1          1.8  virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 3 - Seperate X and Y(species)

# %%
X = df.drop(columns=["species"])
Y = df[["species"]]

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
Y.head()
# Out:
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
Y.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     49
# Name: count, dtype: int64

# %% [markdown]
# ### Step 4 - Preprocessing on X

# %%
X.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# dtype: object

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = make_pipeline(
    SimpleImputer(strategy="median"),
    StandardScaler()
).set_output(transform="pandas")

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0     -0.898033     1.012401     -1.333255    -1.308624
# 1     -1.139562    -0.137353     -1.333255    -1.308624
# 2     -1.381091     0.322549     -1.390014    -1.308624
# 3     -1.501855     0.092598     -1.276496    -1.308624
# 4     -1.018798     1.242352     -1.333255    -1.308624

# %% [markdown]
# ### Step 5- Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X_pre, Y, test_size=0.33, random_state=42)

# %%
xtrain.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 95      -0.173447    -0.137353      0.255985     0.007064
# 104      0.792668    -0.137353      1.164122     1.322752
# 66      -0.294211    -0.137353      0.426261     0.401770
# 0       -0.898033     1.012401     -1.333255    -1.308624
# 141      1.275726     0.092598      0.766812     1.454321

# %%
ytrain.head()
# Out:
#         species
# 95   versicolor
# 104   virginica
# 66   versicolor
# 0        setosa
# 141   virginica

# %%
xtest.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 73       0.309611    -0.597255      0.539778     0.007064
# 18      -0.173447     1.702254     -1.162979    -1.177055
# 117      2.241842     1.702254      1.674949     1.322752
# 78       0.188846    -0.367304      0.426261     0.401770
# 76       1.154962    -0.597255      0.596536     0.270202

# %%
ytest.head()
# Out:
#         species
# 73   versicolor
# 18       setosa
# 117   virginica
# 78   versicolor
# 76   versicolor

# %%
xtrain.shape
# Out:
# (99, 4)

# %%
xtest.shape
# Out:
# (50, 4)

# %% [markdown]
# ### Step 6 - Model building and tuning

# %%
from sklearn.neighbors import KNeighborsClassifier
model1 = KNeighborsClassifier(n_neighbors= 40)
model1.fit(xtrain, ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=40)

# %%
model1.score(xtrain, ytrain)
# Out:
# 0.8686868686868687

# %%
model1.score(xtest, ytest)
# Out:
# 0.9

# %% [markdown]
# ### Hyperparameter tuning

# %%
params = {
    "n_neighbors":[4, 5, 6, 7, 8, 9, 10, 11, 12]
}

# %%
from sklearn.model_selection import GridSearchCV
knn = KNeighborsClassifier()
gscv_knn = GridSearchCV(estimator= knn, param_grid=params, cv = 5,scoring= "f1_macro")
gscv_knn.fit(xtrain, ytrain)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [4, 5, 6, 7, 8, 9, 10, 11, 12]},
#              scoring='f1_macro')

# %%
gscv_knn.best_params_
# Out:
# {'n_neighbors': 5}

# %%
gscv_knn.best_score_
# Out:
# np.float64(0.9011538461538461)

# %%
best_knn = gscv_knn.best_estimator_
best_knn
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### Evaluate the model

# %%
best_knn.score(xtrain, ytrain)
# Out:
# 0.9494949494949495

# %%
best_knn.score(xtest, ytest)
# Out:
# 1.0

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(best_knn, xtrain, ytrain)

# %%
ConfusionMatrixDisplay.from_estimator(best_knn, xtest, ytest)

# %%
ypred_train = best_knn.predict(xtrain)
ypred_test = best_knn.predict(xtest)

# %%
ypred_test[0:5]
# Out:
# array(['versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor'],
#       dtype=object)

# %%
ytest.head()
# Out:
#         species
# 73   versicolor
# 18       setosa
# 117   virginica
# 78   versicolor
# 76   versicolor

# %%
from sklearn.metrics import classification_report
print(classification_report(ytrain, ypred_train))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        31
#   versicolor       0.92      0.94      0.93        35
#    virginica       0.94      0.91      0.92        33
#
#     accuracy                           0.95        99
#    macro avg       0.95      0.95      0.95        99
# weighted avg       0.95      0.95      0.95        99

# %%
print(classification_report(ytest, ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        15
#    virginica       1.00      1.00      1.00        16
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50

# %% [markdown]
# ### SVM (Support Vector Machines)
# ![image.png](attachment:image.png)

# %%
from sklearn.svm import SVC
svm_model = SVC(probability=True)
svm_model.fit(xtrain, ytrain)
# Out:
# SVC(probability=True)

# %% [markdown]
# ### Evaluate SVM model

# %%
svm_model.score(xtrain, ytrain)
# Out:
# 0.9595959595959596

# %%
svm_model.score(xtest, ytest)
# Out:
# 1.0

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(svm_model, xtrain, ytrain, cv=5, scoring="f1_macro")
scores
# Out:
# array([0.95213675, 0.80952381, 0.90277778, 1.        , 0.94747475])

# %%
scores.mean()
# Out:
# np.float64(0.9223826173826174)

# %%
scores_knn = cross_val_score(best_knn, xtrain, ytrain, cv=5, scoring="f1_macro")
scores_knn
# Out:
# array([0.90277778, 0.85641026, 0.90277778, 0.95213675, 0.89166667])

# %%
scores_knn.mean()
# Out:
# np.float64(0.9011538461538461)

# %%
ConfusionMatrixDisplay.from_estimator(svm_model, xtrain, ytrain)

# %%
ConfusionMatrixDisplay.from_estimator(svm_model, xtest, ytest)

# %%
ypred_test2 = svm_model.predict(xtest)

# %%
ypred_test2[0:5]
# Out:
# array(['versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor'],
#       dtype=object)

# %%
ytest.head()
# Out:
#         species
# 73   versicolor
# 18       setosa
# 117   virginica
# 78   versicolor
# 76   versicolor

# %%
print(classification_report(ytest, ypred_test2))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        15
#    virginica       1.00      1.00      1.00        16
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50

# %% [markdown]
# ### Based on cross validated f1 macro SVM has slightly better result of 0.9223 compared to KNN(0.90)

# %% [markdown]
# ### Hence i will choose SVM for out of sample prediction

# %% [markdown]
# ### Step 8- Out of sample prediction

# %%
xnew = pd.read_csv("iris_sample.csv")
xnew
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0            5.5          2.5           4.0          1.3
# 1            6.9          3.1           5.1          2.3
# 2            5.1          2.5           3.0          1.1
# 3            4.4          2.9           NaN          0.2
# 4            5.9          3.0           5.1          1.8
# 5            5.5          3.5           1.3          0.2
# 6            5.6          NaN           3.6          1.3
# 7            6.5          3.0           5.2          2.0
# 8            5.3          3.7           1.5          0.2
# 9            5.1          3.4           1.5          NaN
# 10           6.1          2.8           4.0          1.3
# 11           5.5          2.4           3.7          1.0
# 12           7.7          3.0           6.1          2.3
# 13           6.9          3.1           4.9          1.5
# 14           6.0          2.2           5.0          1.5

# %%
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler())])

# %%
xnew_pre = num_pipe.transform(xnew)
xnew_pre
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0      -0.414976    -1.287108      0.142468     0.138633
# 1       1.275726     0.092598      0.766812     1.454321
# 2      -0.898033    -1.287108     -0.425118    -0.124505
# 3      -1.743384    -0.367304      0.312744    -1.308624
# 4       0.068082    -0.137353      0.766812     0.796477
# 5      -0.414976     1.012401     -1.390014    -1.308624
# 6      -0.294211    -0.137353     -0.084566     0.138633
# 7       0.792668    -0.137353      0.823571     1.059614
# 8      -0.656505     1.472303     -1.276496    -1.308624
# 9      -0.898033     0.782450     -1.276496     0.138633
# 10      0.309611    -0.597255      0.142468     0.138633
# 11     -0.414976    -1.517058     -0.027808    -0.256073
# 12      2.241842    -0.137353      1.334398     1.454321
# 13      1.275726     0.092598      0.653295     0.401770
# 14      0.188846    -1.976960      0.710054     0.401770

# %%
preds = svm_model.predict(xnew_pre)
preds
# Out:
# array(['versicolor', 'virginica', 'versicolor', 'setosa', 'virginica',
#        'setosa', 'versicolor', 'virginica', 'setosa', 'setosa',
#        'versicolor', 'versicolor', 'virginica', 'versicolor',
#        'versicolor'], dtype=object)

# %%
probs = svm_model.predict_proba(xnew_pre)
probs
# Out:
# array([[0.00788599, 0.96567918, 0.02643483],
#        [0.01271665, 0.02042234, 0.96686101],
#        [0.034052  , 0.94982046, 0.01612753],
#        [0.52044719, 0.37292753, 0.10662528],
#        [0.01234236, 0.21678397, 0.77087367],
#        [0.96248929, 0.01956522, 0.01794548],
#        [0.03761267, 0.95176414, 0.01062319],
#        [0.00910885, 0.03450033, 0.95639082],
#        [0.96876614, 0.01570255, 0.01553131],
#        [0.78269571, 0.15199419, 0.06531011],
#        [0.01274909, 0.97914183, 0.00810909],
#        [0.01319215, 0.97847355, 0.0083343 ],
#        [0.02273062, 0.02525023, 0.95201915],
#        [0.01982733, 0.7156302 , 0.26454247],
#        [0.020771  , 0.50597582, 0.47325318]])

# %%
svm_model.classes_
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
xnew["species_pred"] = preds
xnew[svm_model.classes_] = probs

# %%
xnew = xnew.round(4)
xnew
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species_pred  setosa  \
# 0            5.5          2.5           4.0          1.3   versicolor  0.0079
# 1            6.9          3.1           5.1          2.3    virginica  0.0127
# 2            5.1          2.5           3.0          1.1   versicolor  0.0341
# 3            4.4          2.9           NaN          0.2       setosa  0.5204
# 4            5.9          3.0           5.1          1.8    virginica  0.0123
# 5            5.5          3.5           1.3          0.2       setosa  0.9625
# 6            5.6          NaN           3.6          1.3   versicolor  0.0376
# 7            6.5          3.0           5.2          2.0    virginica  0.0091
# 8            5.3          3.7           1.5          0.2       setosa  0.9688
# 9            5.1          3.4           1.5          NaN       setosa  0.7827
# 10           6.1          2.8           4.0          1.3   versicolor  0.0127
# 11           5.5          2.4           3.7          1.0   versicolor  0.0132
# 12           7.7          3.0           6.1          2.3    virginica  0.0227
# 13           6.9          3.1           4.9          1.5   versicolor  0.0198
# 14           6.0          2.2           5.0          1.5   versicolor  0.0208
#
#     versicolor  virginica
# 0       0.9657     0.0264
# 1       0.0204     0.9669
# 2       0.9498     0.0161
# 3       0.3729     0.1066
# 4       0.2168     0.7709
# 5       0.0196     0.0179
# 6       0.9518     0.0106
# 7       0.0345     0.9564
# 8       0.0157     0.0155
# 9       0.1520     0.0653
# 10      0.9791     0.0081
# 11      0.9785     0.0083
# 12      0.0253     0.9520
# 13      0.7156     0.2645
# 14      0.5060     0.4733

# %%
xnew.to_csv("SVMResults.csv", index=False)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 144           6.7          3.0           5.2          2.3  virginica
# 145           6.3          2.5           5.0          1.9  virginica
# 146           6.5          3.0           5.2          2.0  virginica
# 147           6.2          3.4           5.4          2.3  virginica
# 148           5.9          3.0           5.1          1.8  virginica
#
# [149 rows x 5 columns]

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.shape
# Out:
# (149, 5)

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=149, step=1)

# %%
df.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'setosa'],
#        [4.8, 3.4, 1.9, 0.2, 'setosa'],
#        [5.0, 3.0, 1.6, 0.2, 'setosa'],
#        [5.0, 3.4, 1.6, 0.4, 'setosa'],
#        [5.2, 3.5, 1.5, 0.2, 'setosa'],
#        [5.2, 3.4, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.6, 0.2, 'setosa'],
#        [4.8, 3.1, 1.6, 0.2, 'setosa'],
#        [5.4, 3.4, 1.5, 0.4, 'setosa'],
#        [5.2, 4.1, 1.5, 0.1, 'setosa'],
#        [5.5, 4.2, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.2, 1.2, 0.2, 'setosa'],
#        [5.5, 3.5, 1.3, 0.2, 'setosa'],
#        [4.9, 3.6, 1.4, 0.1, 'setosa'],
#        [4.4, 3.0, 1.3, 0.2, 'setosa'],
#        [5.1, 3.4, 1.5, 0.2, 'setosa'],
#        [5.0, 3.5, 1.3, 0.3, 'setosa'],
#        [4.5, 2.3, 1.3, 0.3, 'setosa'],
#        [4.4, 3.2, 1.3, 0.2, 'setosa'],
#        [5.0, 3.5, 1.6, 0.6, 'setosa'],
#        [5.1, 3.8, 1.9, 0.4, 'setosa'],
#        [4.8, 3.0, 1.4, 0.3, 'setosa'],
#        [5.1, 3.8, 1.6, 0.2, 'setosa'],
#        [4.6, 3.2, 1.4, 0.2, 'setosa'],
#        [5.3, 3.7, 1.5, 0.2, 'setosa'],
#        [5.0, 3.3, 1.4, 0.2, 'setosa'],
#        [7.0, 3.2, 4.7, 1.4, 'versicolor'],
#        [6.4, 3.2, 4.5, 1.5, 'versicolor'],
#        [6.9, 3.1, 4.9, 1.5, 'versicolor'],
#        [5.5, 2.3, 4.0, 1.3, 'versicolor'],
#        [6.5, 2.8, 4.6, 1.5, 'versicolor'],
#        [5.7, 2.8, 4.5, 1.3, 'versicolor'],
#        [6.3, 3.3, 4.7, 1.6, 'versicolor'],
#        [4.9, 2.4, 3.3, 1.0, 'versicolor'],
#        [6.6, 2.9, 4.6, 1.3, 'versicolor'],
#        [5.2, 2.7, 3.9, 1.4, 'versicolor'],
#        [5.0, 2.0, 3.5, 1.0, 'versicolor'],
#        [5.9, 3.0, 4.2, 1.5, 'versicolor'],
#        [6.0, 2.2, 4.0, 1.0, 'versicolor'],
#        [6.1, 2.9, 4.7, 1.4, 'versicolor'],
#        [5.6, 2.9, 3.6, 1.3, 'versicolor'],
#        [6.7, 3.1, 4.4, 1.4, 'versicolor'],
#        [5.6, 3.0, 4.5, 1.5, 'versicolor'],
#        [5.8, 2.7, 4.1, 1.0, 'versicolor'],
#        [6.2, 2.2, 4.5, 1.5, 'versicolor'],
#        [5.6, 2.5, 3.9, 1.1, 'versicolor'],
#        [5.9, 3.2, 4.8, 1.8, 'versicolor'],
#        [6.1, 2.8, 4.0, 1.3, 'versicolor'],
#        [6.3, 2.5, 4.9, 1.5, 'versicolor'],
#        [6.1, 2.8, 4.7, 1.2, 'versicolor'],
#        [6.4, 2.9, 4.3, 1.3, 'versicolor'],
#        [6.6, 3.0, 4.4, 1.4, 'versicolor'],
#        [6.8, 2.8, 4.8, 1.4, 'versicolor'],
#        [6.7, 3.0, 5.0, 1.7, 'versicolor'],
#        [6.0, 2.9, 4.5, 1.5, 'versicolor'],
#        [5.7, 2.6, 3.5, 1.0, 'versicolor'],
#        [5.5, 2.4, 3.8, 1.1, 'versicolor'],
#        [5.5, 2.4, 3.7, 1.0, 'versicolor'],
#        [5.8, 2.7, 3.9, 1.2, 'versicolor'],
#        [6.0, 2.7, 5.1, 1.6, 'versicolor'],
#        [5.4, 3.0, 4.5, 1.5, 'versicolor'],
#        [6.0, 3.4, 4.5, 1.6, 'versicolor'],
#        [6.7, 3.1, 4.7, 1.5, 'versicolor'],
#        [6.3, 2.3, 4.4, 1.3, 'versicolor'],
#        [5.6, 3.0, 4.1, 1.3, 'versicolor'],
#        [5.5, 2.5, 4.0, 1.3, 'versicolor'],
#        [5.5, 2.6, 4.4, 1.2, 'versicolor'],
#        [6.1, 3.0, 4.6, 1.4, 'versicolor'],
#        [5.8, 2.6, 4.0, 1.2, 'versicolor'],
#        [5.0, 2.3, 3.3, 1.0, 'versicolor'],
#        [5.6, 2.7, 4.2, 1.3, 'versicolor'],
#        [5.7, 3.0, 4.2, 1.2, 'versicolor'],
#        [5.7, 2.9, 4.2, 1.3, 'versicolor'],
#        [6.2, 2.9, 4.3, 1.3, 'versicolor'],
#        [5.1, 2.5, 3.0, 1.1, 'versicolor'],
#        [5.7, 2.8, 4.1, 1.3, 'versicolor'],
#        [6.3, 3.3, 6.0, 2.5, 'virginica'],
#        [5.8, 2.7, 5.1, 1.9, 'virginica'],
#        [7.1, 3.0, 5.9, 2.1, 'virginica'],
#        [6.3, 2.9, 5.6, 1.8, 'virginica'],
#        [6.5, 3.0, 5.8, 2.2, 'virginica'],
#        [7.6, 3.0, 6.6, 2.1, 'virginica'],
#        [4.9, 2.5, 4.5, 1.7, 'virginica'],
#        [7.3, 2.9, 6.3, 1.8, 'virginica'],
#        [6.7, 2.5, 5.8, 1.8, 'virginica'],
#        [7.2, 3.6, 6.1, 2.5, 'virginica'],
#        [6.5, 3.2, 5.1, 2.0, 'virginica'],
#        [6.4, 2.7, 5.3, 1.9, 'virginica'],
#        [6.8, 3.0, 5.5, 2.1, 'virginica'],
#        [5.7, 2.5, 5.0, 2.0, 'virginica'],
#        [5.8, 2.8, 5.1, 2.4, 'virginica'],
#        [6.4, 3.2, 5.3, 2.3, 'virginica'],
#        [6.5, 3.0, 5.5, 1.8, 'virginica'],
#        [7.7, 3.8, 6.7, 2.2, 'virginica'],
#        [7.7, 2.6, 6.9, 2.3, 'virginica'],
#        [6.0, 2.2, 5.0, 1.5, 'virginica'],
#        [6.9, 3.2, 5.7, 2.3, 'virginica'],
#        [5.6, 2.8, 4.9, 2.0, 'virginica'],
#        [7.7, 2.8, 6.7, 2.0, 'virginica'],
#        [6.3, 2.7, 4.9, 1.8, 'virginica'],
#        [6.7, 3.3, 5.7, 2.1, 'virginica'],
#        [7.2, 3.2, 6.0, 1.8, 'virginica'],
#        [6.2, 2.8, 4.8, 1.8, 'virginica'],
#        [6.1, 3.0, 4.9, 1.8, 'virginica'],
#        [6.4, 2.8, 5.6, 2.1, 'virginica'],
#        [7.2, 3.0, 5.8, 1.6, 'virginica'],
#        [7.4, 2.8, 6.1, 1.9, 'virginica'],
#        [7.9, 3.8, 6.4, 2.0, 'virginica'],
#        [6.4, 2.8, 5.6, 2.2, 'virginica'],
#        [6.3, 2.8, 5.1, 1.5, 'virginica'],
#        [6.1, 2.6, 5.6, 1.4, 'virginica'],
#        [7.7, 3.0, 6.1, 2.3, 'virginica'],
#        [6.3, 3.4, 5.6, 2.4, 'virginica'],
#        [6.4, 3.1, 5.5, 1.8, 'virginica'],
#        [6.0, 3.0, 4.8, 1.8, 'virginica'],
#        [6.9, 3.1, 5.4, 2.1, 'virginica'],
#        [6.7, 3.1, 5.6, 2.4, 'virginica'],
#        [6.9, 3.1, 5.1, 2.3, 'virginica'],
#        [6.8, 3.2, 5.9, 2.3, 'virginica'],
#        [6.7, 3.3, 5.7, 2.5, 'virginica'],
#        [6.7, 3.0, 5.2, 2.3, 'virginica'],
#        [6.3, 2.5, 5.0, 1.9, 'virginica'],
#        [6.5, 3.0, 5.2, 2.0, 'virginica'],
#        [6.2, 3.4, 5.4, 2.3, 'virginica'],
#        [5.9, 3.0, 5.1, 1.8, 'virginica']], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  149 non-null    float64
#  1   sepal_width   149 non-null    float64
#  2   petal_length  149 non-null    float64
#  3   petal_width   149 non-null    float64
#  4   species       149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
